# %%
a = 5
b = 10
print(a+b)
# Out:
# 15

# %%
list = [20,30,50,50,48,49,48]
list.append(320)
list
# Out:
# [20, 30, 50, 50, 48, 49, 48, 320]

# %%
dict = {"name": "Ababio","age": 19, "status": "single"}
dict["name"]
dict["age"]
dict.keys()
dict.values()
# Out:
# dict_values(['Ababio', 19, 'single'])

# %%
company = {"first":["apple","microsoft"],"second":["IBM","amazon"],"third":["cocobod","goggle"]}
company.values()
# Out:
# dict_values([['apple', 'microsoft'], ['IBM', 'amazon'], ['cocobod', 'goggle']])

# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv("PANDA_DATA.csv")

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
dates = pd.DataFrame({"A": [1,2,3],"B":["APPLE","MICROSOFT","GOOGLE"],"C":["2020-04-01","2020-05-01","2020-06-01"]})
dates
# Out:
#    A          B           C
# 0  1      APPLE  2020-04-01
# 1  2  MICROSOFT  2020-05-01
# 2  3     GOOGLE  2020-06-01

# %%
dates.dtypes
# Out:
# A     int64
# B    object
# C    object
# dtype: object

# %%
dates["C"]=pd.to_datetime(dates["C"])

# %%
dates.dtypes
# Out:
# A             int64
# B            object
# C    datetime64[ns]
# dtype: object

# %%
pd.to_datetime(["2020-sep-03","abc"], errors = "coerce")
# Out:
# DatetimeIndex(['2020-09-03', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
df.describe(include = "all")
# Out:
#             Date Customer Acquisition Type    State    Product        Price  \
# count       5780                      5780     5780       5780  5780.000000
# unique      1095                         3        7          5          NaN
# top     1/2/2018                        Ad  Florida  Product 5          NaN
# freq          33                      1982      859       1171          NaN
# mean         NaN                       NaN      NaN        NaN   300.089965
# std          NaN                       NaN      NaN        NaN   141.153833
# min          NaN                       NaN      NaN        NaN    99.000000
# 25%          NaN                       NaN      NaN        NaN   199.000000
# 50%          NaN                       NaN      NaN        NaN   299.000000
# 75%          NaN                       NaN      NaN        NaN   399.000000
# max          NaN                       NaN      NaN        NaN   499.000000
#
# ...

# %%
dashboard = df.loc[:,"Date"]
type(dashboard)
# Out:
# pandas.core.series.Series

# %%
df.loc[0:4,["Date","Customer Acquisition Type","State"]]
# Out:
#        Date Customer Acquisition Type           State
# 0  1/1/2017                        Ad         Florida
# 1  1/1/2017                 Returning  North Carolina
# 2  1/2/2017                   Organic     Mississippi
# 3  1/3/2017                   Organic         Florida
# 4  1/3/2017                 Returning     Mississippi

# %%
df
df.loc[df["Price"] > 200]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8fa7020665a2> in <module>
# ----> 1 df
#       2 df.loc[df["Price"] > 200]
#
# NameError: name 'df' is not defined

# %%
df1 = df.loc[(df["Price"] > 200 ) & (df["State"].isin(["Florida","Georgia"]))]
df1.reset_index(inplace = True, drop = True )

df1
# Out:
#             Date Customer Acquisition Type    State    Product  Price  Units  \
# 0       1/3/2017                 Returning  Florida  Product 1    499      6
# 1       1/3/2017                        Ad  Georgia  Product 5    399      7
# 2       1/3/2017                   Organic  Georgia  Product 1    499      1
# 3       1/5/2017                   Organic  Florida  Product 1    499     10
# 4       1/6/2017                        Ad  Florida  Product 1    499      5
# 5       1/6/2017                 Returning  Georgia  Product 5    399      8
# 6       1/6/2017                   Organic  Georgia  Product 3    299     10
# 7       1/6/2017                 Returning  Florida  Product 3    299      7
# 8       1/7/2017                        Ad  Georgia  Product 5    399      6
# 9       1/8/2017                 Returning  Georgia  Product 5    399      8
# 10     1/10/2017                   Organic  Georgia  Product 1    499      7
# ...

# %%
df.sort_values(by = ["State","Price","Revenue"], ascending = ["True","False","False"])
#df
# Out:
#             Date Customer Acquisition Type      State    Product  Price  \
# 65     1/13/2017                        Ad    Alabama  Product 4     99
# 486    4/13/2017                        Ad    Alabama  Product 4     99
# 584    4/30/2017                 Returning    Alabama  Product 4     99
# 1271   8/21/2017                 Returning    Alabama  Product 4     99
# 1401   9/14/2017                 Returning    Alabama  Product 4     99
# 1696  10/30/2017                   Organic    Alabama  Product 4     99
# 2323   2/17/2018                   Organic    Alabama  Product 4     99
# 3634  10/17/2018                        Ad    Alabama  Product 4     99
# 3844  11/28/2018                   Organic    Alabama  Product 4     99
# 4153   1/29/2019                        Ad    Alabama  Product 4     99
# 4532   4/24/2019                   Organic    Alabama  Product 4     99
# 4667   5/25/2019                        Ad    Alabama  Product 4     99
# ...

# %%
import numpy as np
df["price_value"] = np.where(df["Price"] > 300 , "High Price","Low Price")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-476ae3e31498> in <module>
#       1 import numpy as np
# ----> 2 df["price_value"] = np.where(df["Price"] > 300 , "High Price","Low Price")
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#        Date Customer Acquisition Type           State    Product  Price  \
# 0  1/1/2017                        Ad         Florida  Product 2    199
# 1  1/1/2017                 Returning  North Carolina  Product 3    299
# 2  1/2/2017                   Organic     Mississippi  Product 2    199
# 3  1/3/2017                   Organic         Florida  Product 4     99
# 4  1/3/2017                 Returning     Mississippi  Product 2    199
#
#    Units  Revenue Delivery Performance Return Customer Satisfaction  \
# 0      4      796              on-time     no               (2) low
# 1      9     2691              on-time     no          (1) very low
# 2      6     1194              on-time     no                (3) ok
# 3      3      297              delayed     no               (2) low
# 4      7     1393              on-time     no                (3) ok
#
#   price_value
# 0   Low Price
# 1   Low Price
# 2   Low Price
# 3   Low Price
# 4   Low Price

# %%
df.groupby(["Customer Acquisition Type","State"])["Revenue"].agg(["mean","sum"])
# Out:
#                                                  mean     sum
# Customer Acquisition Type State
# Ad                        Alabama         1700.064748  472618
#                           Florida         1634.897527  462676
#                           Georgia         1566.754266  459059
#                           Mississippi     1704.735395  496078
#                           North Carolina  1708.967972  480220
#                           South Carolina  1656.845324  460603
#                           Tennessee       1492.561151  414932
# Organic                   Alabama         1580.318352  421945
#                           Florida         1716.785714  480700
#                           Georgia         1665.522968  471343
#                           Mississippi     1732.227106  472898
#                           North Carolina  1521.415385  395568
#                           South Carolina  1737.618123  536924
#                           Tennessee       1722.367273  473651
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.dtypes
df.groupby("State")["Revenue","Date"].agg({"Revenue": ["mean"], "Date": ["max","min"]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1042afcf0ae3> in <module>
# ----> 1 df["Date"] = pd.to_datetime(df["Date"])
#       2 df.dtypes
#       3 df.groupby("State")["Revenue","Date"].agg({"Revenue": ["mean"], "Date": ["max","min"]})
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#            Date Customer Acquisition Type           State    Product  Price  \
# 0    2017-01-01                        Ad         Florida  Product 2    199
# 1    2017-01-01                 Returning  North Carolina  Product 3    299
# 2    2017-01-02                   Organic     Mississippi  Product 2    199
# 3    2017-01-03                   Organic         Florida  Product 4     99
# 4    2017-01-03                 Returning     Mississippi  Product 2    199
# 5    2017-01-03                 Returning         Florida  Product 1    499
# 6    2017-01-03                   Organic         Georgia  Product 2    199
# 7    2017-01-03                   Organic  South Carolina  Product 4     99
# 8    2017-01-03                   Organic  South Carolina  Product 3    299
# 9    2017-01-03                        Ad         Georgia  Product 5    399
# 10   2017-01-03                 Returning     Mississippi  Product 5    399
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv("PANDA_DATA.csv")

# %%
df
df["Date"] = pd.to_datetime(df["Date"])
df_group = df.groupby("State")["Price","Date"].agg({"Price": ["mean"], "Date": ["max","min"]})
df_group.reset_index(inplace = True)
df_group.columns = ["STATES","MEAN PRICE","LATE DELIVERY","EARLY DELIVERY"]
df_group
# Out:
#            STATES  MEAN PRICE LATE DELIVERY EARLY DELIVERY
# 0         Alabama  304.603985    2019-12-31     2017-01-03
# 1         Florida  297.253783    2019-12-30     2017-01-01
# 2         Georgia  301.615933    2019-12-31     2017-01-03
# 3     Mississippi  295.282528    2019-12-30     2017-01-02
# 4  North Carolina  300.364764    2019-12-30     2017-01-01
# 5  South Carolina  301.573099    2019-12-31     2017-01-03
# 6       Tennessee  299.988875    2019-12-31     2017-01-06

# %%
df["Date"] = pd.to_datetime(df["Date"])
df_group = df.groupby("State")["Price","Date"].agg({"Price": ["mean"], "Date": ["max","min"]})
df_group.reset_index(inplace = True)
df_group.columns = ["STATES","MEAN_PRICE","LATE_DELIVERY","EARLY_DELIVERY"]
df_group
df_group.to_csv("ababio.csv")

# %%
a = [20,30,40,50,60]
a
b = [a[0],a[3]]
b
a.append(60)
a
# Out:
# [20, 30, 40, 50, 60, 60]

# %% [markdown]
# #this is very difficult

# %%
import pandas as pd
df = pd.read_csv("PANDA_DATA.csv")
df
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 0       1/1/2017                        Ad         Florida  Product 2    199
# 1       1/1/2017                 Returning  North Carolina  Product 3    299
# 2       1/2/2017                   Organic     Mississippi  Product 2    199
# 3       1/3/2017                   Organic         Florida  Product 4     99
# 4       1/3/2017                 Returning     Mississippi  Product 2    199
# 5       1/3/2017                 Returning         Florida  Product 1    499
# 6       1/3/2017                   Organic         Georgia  Product 2    199
# 7       1/3/2017                   Organic  South Carolina  Product 4     99
# 8       1/3/2017                   Organic  South Carolina  Product 3    299
# 9       1/3/2017                        Ad         Georgia  Product 5    399
# 10      1/3/2017                 Returning     Mississippi  Product 5    399
# ...

# %%
df.head()
df.shape
# Out:
# (5780, 10)

# %%
change = pd.DataFrame({"Microsoft":["Sundar","Bill","Balmer"],"Google":["Paige","Sundar","Allen"],"Date":["21-01-2021","22-01-2021","23-01-2021"]})
change
# Out:
#   Microsoft  Google        Date
# 0    Sundar   Paige  21-01-2021
# 1      Bill  Sundar  22-01-2021
# 2    Balmer   Allen  23-01-2021

# %%
change.dtypes
pd.to_datetime("2021-01-23")
change["Date"] = pd.to_datetime(change["Date"])

# %%
change
# Out:
#   Microsoft  Google       Date
# 0    Sundar   Paige 2021-01-21
# 1      Bill  Sundar 2021-01-22
# 2    Balmer   Allen 2021-01-23

# %%
change.dtypes
# Out:
# Microsoft            object
# Google               object
# Date         datetime64[ns]
# dtype: object

# %%
df.describe(include = "all")
# Out:
#             Date Customer Acquisition Type    State    Product        Price  \
# count       5780                      5780     5780       5780  5780.000000
# unique      1095                         3        7          5          NaN
# top     1/2/2018                        Ad  Florida  Product 5          NaN
# freq          33                      1982      859       1171          NaN
# mean         NaN                       NaN      NaN        NaN   300.089965
# std          NaN                       NaN      NaN        NaN   141.153833
# min          NaN                       NaN      NaN        NaN    99.000000
# 25%          NaN                       NaN      NaN        NaN   199.000000
# 50%          NaN                       NaN      NaN        NaN   299.000000
# 75%          NaN                       NaN      NaN        NaN   399.000000
# max          NaN                       NaN      NaN        NaN   499.000000
#
# ...

# %%
df["State"].value_counts()
# Out:
# Florida           859
# South Carolina    855
# Georgia           841
# Tennessee         809
# Mississippi       807
# North Carolina    806
# Alabama           803
# Name: State, dtype: int64

# %%
import pandas as pd
df = pd.read_csv("PANDA_DATA.csv")

# %%
a = df.head()
a
a.iloc[0:5,0:3]
# Out:
#        Date Customer Acquisition Type           State
# 0  1/1/2017                        Ad         Florida
# 1  1/1/2017                 Returning  North Carolina
# 2  1/2/2017                   Organic     Mississippi
# 3  1/3/2017                   Organic         Florida
# 4  1/3/2017                 Returning     Mississippi

# %%
import pandas as pd
df = pd.read_csv("PANDA_DATA.csv")
df
# Out:
#       01/01/2017         Ad         Florida  Product 2  199   4   796  \
# 0     01/01/2017  Returning  North Carolina  Product 3  299   9  2691
# 1     01/02/2017    Organic     Mississippi  Product 2  199   6  1194
# 2     01/03/2017    Organic         Florida  Product 4   99   3   297
# 3     01/03/2017  Returning     Mississippi  Product 2  199   7  1393
# 4     01/03/2017  Returning         Florida  Product 1  499   6  2994
# 5     01/03/2017    Organic         Georgia  Product 2  199   4   796
# 6     01/03/2017    Organic  South Carolina  Product 4   99   5   495
# 7     01/03/2017    Organic  South Carolina  Product 3  299   1   299
# 8     01/03/2017         Ad         Georgia  Product 5  399   7  2793
# 9     01/03/2017  Returning     Mississippi  Product 5  399   1   399
# 10    01/03/2017         Ad         Alabama  Product 3  299   4  1196
# 11    01/03/2017  Returning  North Carolina  Product 2  199   4   796
# ...

# %%
df.iloc[:,: -1]
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 0       1/1/2017                        Ad         Florida  Product 2    199
# 1       1/1/2017                 Returning  North Carolina  Product 3    299
# 2       1/2/2017                   Organic     Mississippi  Product 2    199
# 3       1/3/2017                   Organic         Florida  Product 4     99
# 4       1/3/2017                 Returning     Mississippi  Product 2    199
# 5       1/3/2017                 Returning         Florida  Product 1    499
# 6       1/3/2017                   Organic         Georgia  Product 2    199
# 7       1/3/2017                   Organic  South Carolina  Product 4     99
# 8       1/3/2017                   Organic  South Carolina  Product 3    299
# 9       1/3/2017                        Ad         Georgia  Product 5    399
# 10      1/3/2017                 Returning     Mississippi  Product 5    399
# ...

# %%
df.loc[0:4,["Date","Product"]]
# Out:
#        Date    Product
# 0  1/1/2017  Product 2
# 1  1/1/2017  Product 3
# 2  1/2/2017  Product 2
# 3  1/3/2017  Product 4
# 4  1/3/2017  Product 2

# %%
df.iloc[0:5,[0,3]]
# Out:
#        Date    Product
# 0  1/1/2017  Product 2
# 1  1/1/2017  Product 3
# 2  1/2/2017  Product 2
# 3  1/3/2017  Product 4
# 4  1/3/2017  Product 2

# %%
df.loc[df["Price"] > 299, ["Date","Price"]]
# Out:
#             Date  Price
# 5       1/3/2017    499
# 9       1/3/2017    399
# 10      1/3/2017    399
# 13      1/3/2017    499
# 15      1/3/2017    499
# 18      1/5/2017    499
# 22      1/6/2017    499
# 23      1/6/2017    499
# 24      1/6/2017    399
# 25      1/6/2017    499
# 29      1/6/2017    499
# 31      1/6/2017    399
# 38      1/6/2017    399
# 42      1/7/2017    399
# 43      1/7/2017    499
# 44      1/8/2017    399
# 48     1/10/2017    499
# 50     1/10/2017    499
# 52     1/10/2017    499
# 56     1/12/2017    399
# 64     1/13/2017    499
# 69     1/13/2017    399
# 70     1/13/2017    499
# 71     1/13/2017    499
# 73     1/13/2017    399
# 76     1/15/2017    499
# 82     1/16/2017    399
# 85     1/17/2017    499
# 87     1/17/2017    399
# 88     1/17/2017    399
# ...          ...    ...
# 5708  12/15/2019    399
# 5717  12/18/2019    499
# 5719  12/18/2019    499
# 5721  12/19/2019    399
# 5723  12/19/2019    499
# 5724  12/19/2019    399
# ...

# %%
df[df["Price"] > 299]
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 5       1/3/2017                 Returning         Florida  Product 1    499
# 9       1/3/2017                        Ad         Georgia  Product 5    399
# 10      1/3/2017                 Returning     Mississippi  Product 5    399
# 13      1/3/2017                        Ad         Alabama  Product 1    499
# 15      1/3/2017                   Organic         Georgia  Product 1    499
# 18      1/5/2017                   Organic         Florida  Product 1    499
# 22      1/6/2017                        Ad     Mississippi  Product 1    499
# 23      1/6/2017                   Organic     Mississippi  Product 1    499
# 24      1/6/2017                        Ad       Tennessee  Product 5    399
# 25      1/6/2017                        Ad         Florida  Product 1    499
# 29      1/6/2017                 Returning  North Carolina  Product 1    499
# ...

# %%
df.loc[df["State"] == "Florida", ["Product","Price"]]
df[df["Customer Acquisition Type"].isin(["Ad","Organic"])]
#df[(df["Revenue"] > 400) & (df["Customer Acquisition Type"].isin(["Ad","Organic"]))]
df[df["Revenue"] > 400 & df["Customer Acquisition Type"].isin(["Ad","Organic"])]
df1 = df[(df["Revenue"] > 400) & (df["Customer Acquisition Type"].isin(["Ad","Organic"]))]
df1.reset_index(inplace = True, drop = True)
df1
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 0       1/1/2017                        Ad         Florida  Product 2    199
# 1       1/2/2017                   Organic     Mississippi  Product 2    199
# 2       1/3/2017                   Organic         Georgia  Product 2    199
# 3       1/3/2017                   Organic  South Carolina  Product 4     99
# 4       1/3/2017                        Ad         Georgia  Product 5    399
# 5       1/3/2017                        Ad         Alabama  Product 3    299
# 6       1/3/2017                        Ad         Alabama  Product 1    499
# 7       1/3/2017                   Organic         Georgia  Product 1    499
# 8       1/3/2017                   Organic  South Carolina  Product 4     99
# 9       1/4/2017                        Ad  North Carolina  Product 4     99
# 10      1/5/2017                   Organic         Florida  Product 1    499
# ...

# %%
df.sort_values(by=["State", "Customer Acquisition Type"], ascending = [True,False])
# Out:
#             Date Customer Acquisition Type      State    Product  Price  \
# 14      1/3/2017                 Returning    Alabama  Product 4     99
# 79     1/15/2017                 Returning    Alabama  Product 4     99
# 89     1/18/2017                 Returning    Alabama  Product 3    299
# 109    1/21/2017                 Returning    Alabama  Product 1    499
# 124    1/27/2017                 Returning    Alabama  Product 4     99
# 147     2/1/2017                 Returning    Alabama  Product 5    399
# 162     2/6/2017                 Returning    Alabama  Product 5    399
# 181    2/10/2017                 Returning    Alabama  Product 5    399
# 187    2/10/2017                 Returning    Alabama  Product 2    199
# 206    2/17/2017                 Returning    Alabama  Product 3    299
# 234    2/21/2017                 Returning    Alabama  Product 3    299
# 240    2/22/2017                 Returning    Alabama  Product 5    399
# ...

# %%
df
# Out:
#       01/01/2017         Ad         Florida  Product 2  199   4   796  \
# 0     01/01/2017  Returning  North Carolina  Product 3  299   9  2691
# 1     01/02/2017    Organic     Mississippi  Product 2  199   6  1194
# 2     01/03/2017    Organic         Florida  Product 4   99   3   297
# 3     01/03/2017  Returning     Mississippi  Product 2  199   7  1393
# 4     01/03/2017  Returning         Florida  Product 1  499   6  2994
# 5     01/03/2017    Organic         Georgia  Product 2  199   4   796
# 6     01/03/2017    Organic  South Carolina  Product 4   99   5   495
# 7     01/03/2017    Organic  South Carolina  Product 3  299   1   299
# 8     01/03/2017         Ad         Georgia  Product 5  399   7  2793
# 9     01/03/2017  Returning     Mississippi  Product 5  399   1   399
# 10    01/03/2017         Ad         Alabama  Product 3  299   4  1196
# 11    01/03/2017  Returning  North Carolina  Product 2  199   4   796
# ...

# %%
import
# Out:
#       01/01/2017         Ad         Florida  Product 2  199   4   796  \
# 0     01/01/2017  Returning  North Carolina  Product 3  299   9  2691
# 1     01/02/2017    Organic     Mississippi  Product 2  199   6  1194
# 2     01/03/2017    Organic         Florida  Product 4   99   3   297
# 3     01/03/2017  Returning     Mississippi  Product 2  199   7  1393
# 4     01/03/2017  Returning         Florida  Product 1  499   6  2994
# 5     01/03/2017    Organic         Georgia  Product 2  199   4   796
# 6     01/03/2017    Organic  South Carolina  Product 4   99   5   495
# 7     01/03/2017    Organic  South Carolina  Product 3  299   1   299
# 8     01/03/2017         Ad         Georgia  Product 5  399   7  2793
# 9     01/03/2017  Returning     Mississippi  Product 5  399   1   399
# 10    01/03/2017         Ad         Alabama  Product 3  299   4  1196
# 11    01/03/2017  Returning  North Carolina  Product 2  199   4   796
# ...

# %%
import pandas as pd
df = pd.read_csv("PANDA_DATA.csv")
df
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 0       1/1/2017                        Ad         Florida  Product 2    199
# 1       1/1/2017                 Returning  North Carolina  Product 3    299
# 2       1/2/2017                   Organic     Mississippi  Product 2    199
# 3       1/3/2017                   Organic         Florida  Product 4     99
# 4       1/3/2017                 Returning     Mississippi  Product 2    199
# 5       1/3/2017                 Returning         Florida  Product 1    499
# 6       1/3/2017                   Organic         Georgia  Product 2    199
# 7       1/3/2017                   Organic  South Carolina  Product 4     99
# 8       1/3/2017                   Organic  South Carolina  Product 3    299
# 9       1/3/2017                        Ad         Georgia  Product 5    399
# 10      1/3/2017                 Returning     Mississippi  Product 5    399
# ...

# %%
import numpy as np 
df["Price_Medium"] = np.where(df["Price"] < 200, "Low Price ",np.where(df["Price"] == 499, "High Price","Medium Price"))
df
# Out:
#             Date Customer Acquisition Type           State    Product  Price  \
# 0       1/1/2017                        Ad         Florida  Product 2    199
# 1       1/1/2017                 Returning  North Carolina  Product 3    299
# 2       1/2/2017                   Organic     Mississippi  Product 2    199
# 3       1/3/2017                   Organic         Florida  Product 4     99
# 4       1/3/2017                 Returning     Mississippi  Product 2    199
# 5       1/3/2017                 Returning         Florida  Product 1    499
# 6       1/3/2017                   Organic         Georgia  Product 2    199
# 7       1/3/2017                   Organic  South Carolina  Product 4     99
# 8       1/3/2017                   Organic  South Carolina  Product 3    299
# 9       1/3/2017                        Ad         Georgia  Product 5    399
# 10      1/3/2017                 Returning     Mississippi  Product 5    399
# ...

# %%
df.groupby("State")["Revenue"].agg("mean")
df.groupby("Customer Acquisition Type").mean()
# Out:
#                                 Price     Units      Revenue
# Customer Acquisition Type
# Ad                         298.243189  5.405651  1637.833502
# Organic                    299.205444  5.583462  1670.790447
# Returning                  302.997839  5.481902  1667.559697

# %%
df.groupby(["State","Customer Acquisition Type"])["Price"].agg(["sum","mean"])
# Out:
#                                             sum        mean
# State          Customer Acquisition Type
# Alabama        Ad                         86722  311.949640
#                Organic                    79133  296.378277
#                Returning                  78742  305.201550
# Florida        Ad                         85517  302.180212
#                Organic                    84320  301.142857
#                Returning                  85504  288.864865
# Georgia        Ad                         85407  291.491468
#                Organic                    85417  301.826855
#                Returning                  82835  312.584906
# Mississippi    Ad                         85109  292.470790
#                Organic                    79527  291.307692
#                Returning                  73657  303.115226
# North Carolina Ad                         84119  299.355872
#                Organic                    75940  292.076923
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.dtypes
new = df.groupby("State").agg({"Date":["max","min"],"Price":["mean"]})
new.reset_index(inplace = True)
new.columns = ["STATE","LATE DATE", "EARLY DATE", "MEAN PRICE"]
new.to_csv("new.csv")
